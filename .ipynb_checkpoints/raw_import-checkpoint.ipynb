# %%
import rawpy
import imageio

path = '/Users/danijelmaricic/Downloads/Image__2024-05-31__14-08-37.raw'
with rawpy.imread(path) as raw:
    rgb = raw.postprocess()
imageio.imsave('default.tiff', rgb)
# Out:
# ---------------------------------------------------------------------------
# LibRawFileUnsupportedError                Traceback (most recent call last)
# Cell In[5], line 5
#       2 import imageio
#       4 path = '/Users/danijelmaricic/Downloads/Image__2024-05-31__14-08-37.raw'
# ----> 5 with rawpy.imread(path) as raw:
#       6     rgb = raw.postprocess()
#       7 imageio.imsave('default.tiff', rgb)
#
# File ~/.pyenv/versions/3.12.3/envs/jupyter_env/lib/python3.12/site-packages/rawpy/__init__.py:20, in imread(pathOrFile)
#      18     d.open_buffer(pathOrFile)
#      19 else:
# ---> 20     d.open_file(pathOrFile)
#      21 return d
#
# File rawpy/_rawpy.pyx:411, in rawpy._rawpy.RawPy.open_file()
#
# File rawpy/_rawpy.pyx:950, in rawpy._rawpy.RawPy.handle_error()
#
# LibRawFileUnsupportedError: b'Unsupported file format or not RAW file'

# %%
ls -rtl path
# Out:
# ls: path: No such file or directory

# %%
import numpy as np
from PIL import Image
from pathlib import Path
path1 = '/Users/danijelmaricic/Downloads/'
file_name = 'Image__2024-05-31__14-08-37.raw'
file_name_only = Path(file_name).stem
file_name_raw = file_name_only + '-OUT.RAW'

# %%
def read_write_raw(): 
    with open(path1 + file_name, 'r') as infile:
        data = np.fromfile(infile, dtype=np.uint8) 
        pixels, = data.shape 
        height = int(2160) 
        width = int(pixels / height) 
        data = np.reshape(data, (height, width)) 
        im = Image.fromarray(data) 
        im.save('template1.png') 
        data.astype(np.uint16).tofile(path1 + file_name_raw)

# %%
read_write_raw()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 read_write_raw()
#
# Cell In[15], line 8, in read_write_raw()
#       6 width = int(pixels / height)
#       7 data = np.reshape(data, (height, width))
# ----> 8 im = Image.fromarray(data)
#       9 im.save('template1.png')
#      10 data.astype(np.uint16).tofile(path1 + file_name_raw)
#
# NameError: name 'Image' is not defined
